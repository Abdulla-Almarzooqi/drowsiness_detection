# %%
from ultralytics import RTDETR

# Load a COCO-pretrained RT-DETR-x model
model = RTDETR('rtdetr-x.pt')

# Train the model on the dataset for 30 epochs
# Note: place path to custom YAML file (created in YOLOv8 notebook) in the 'data' argument below
results = model.train(data='/home/abdulrahman.almarzoo/Desktop/AI702Proj/Drowsiness-/-Fatigue_Detection-4/data.yaml', 
    epochs=30, 
    batch=16, 
    imgsz=640, 
    lr0=0.001, 
    lrf=0.1, 
    momentum=0.9, 
    weight_decay=0.001, 
    label_smoothing=0.1, 
    nbs=16, 
    dropout=0.35
)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.13 torch-2.0.0 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# ...

# %%
from IPython.display import Image

# Display confusion matrix (change path accordingly)
Image(filename=f'/home/abdulrahman.almarzoo/Desktop/AI702Proj/runs/detect/train15/confusion_matrix.png', width=600)

# %%
# Display plots (change path accordingly)
Image(filename=f'/home/abdulrahman.almarzoo/Desktop/AI702Proj/runs/detect/train15/results.png', width=600)

# %%
# (change path accordingly)
model = RTDETR(f'/home/abdulrahman.almarzoo/Desktop/AI702Proj/runs/detect/train15/weights/best.pt')

# Display metrics
# Note: place path to custom YAML file (created in YOLOv8 notebook) in the 'data' argument below
results = model.val(
    data='/home/abdulrahman.almarzoo/Desktop/AI702Proj/Drowsiness-/-Fatigue_Detection-4/data.yaml',
    save=True
)
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.13 torch-2.0.0 CUDA:0 (Quadro RTX 6000, 24190MiB)
# rt-detr-x summary: 642 layers, 65471546 parameters, 0 gradients, 222.5 GFLOPs
# val: Scanning /home/abdulrahman.almarzoo/Desktop/AI702Proj/Drowsiness-/-Fatigue_Detection-4/valid/labels.cache... 814 images, 0 backgrounds, 0 corrupt: 100%|██████████| 814/814 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 51/51 [00:21<00:00,  2.35it/s]
#                    all        814        814      0.977      0.979      0.972       0.77
#                  alert        814        234      0.966      0.974      0.962      0.751
#                 drowsy        814        580      0.988      0.984      0.982      0.789
# Speed: 0.4ms preprocess, 19.5ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs/detect/val2

# %%
# Predict test images

# Note: place path to custom YAML file (created in YOLOv8 notebook) in the 'data' argument below
# Change path of the 'source' argument as required
results = model.predict(
    data='/home/abdulrahman.almarzoo/Desktop/AI702Proj/Drowsiness-/-Fatigue_Detection-4/data.yaml',
    conf=0.25,
    iou=0.45,
    source='/home/abdulrahman.almarzoo/Desktop/AI702Proj/Drowsiness-/-Fatigue_Detection-4/test/images',
    save=True
)
# Out:
# image 1/482 /home/abdulrahman.almarzoo/Desktop/AI702Proj/Drowsiness-/-Fatigue_Detection-4/test/images/100_jpg.rf.6a0d7bb927a1415b56244b85659737aa.jpg: 640x640 1 alert, 70.0ms
# image 2/482 /home/abdulrahman.almarzoo/Desktop/AI702Proj/Drowsiness-/-Fatigue_Detection-4/test/images/102_jpg.rf.199ea73832422606f6fb641c0defabec.jpg: 640x640 1 alert, 60.2ms
# image 3/482 /home/abdulrahman.almarzoo/Desktop/AI702Proj/Drowsiness-/-Fatigue_Detection-4/test/images/104_jpg.rf.59a14a0746ad500c90087f0d769ea0f7.jpg: 640x640 1 alert, 64.3ms
# image 4/482 /home/abdulrahman.almarzoo/Desktop/AI702Proj/Drowsiness-/-Fatigue_Detection-4/test/images/111_jpg.rf.4971ee203e16140f81fe387c7b84e166.jpg: 640x640 1 alert, 70.3ms
# image 5/482 /home/abdulrahman.almarzoo/Desktop/AI702Proj/Drowsiness-/-Fatigue_Detection-4/test/images/156_jpg.rf.6bb2d45efb9fa41988322306d02370ac.jpg: 640x640 1 drowsy, 63.3ms
# ...

# %%
import glob
from IPython.display import display

# Display some predicted images (change path accordingly)
for image_path in glob.glob(f'/home/abdulrahman.almarzoo/Desktop/AI702Proj/runs/detect/predict/*.jpg')[35:37]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
# Export the model
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.13 torch-2.0.0 CPU (Intel Xeon Silver 4215 2.50GHz)
# rt-detr-x summary: 642 layers, 65471546 parameters, 0 gradients, 222.5 GFLOPs
#
# PyTorch: starting from '/home/abdulrahman.almarzoo/Desktop/AI702Proj/runs/detect/train15/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (129.1 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 25.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.8/302.8 kB 470.9 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 32.8s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.16.0 opset 17...
# ================ Diagnostic Run torch.onnx.export version 2.0.0 ================
# verbose: False, log level: Level.ERROR
# ...
